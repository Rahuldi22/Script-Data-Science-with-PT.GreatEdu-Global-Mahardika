# %%
import pandas as pd
import numpy as np

#untuk dapat melihat seluruh kolom dan baris
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
data_mahasiswa = {
    'NIM': ['101', '102', '103', '104', '105', '106', '107', '108', '109', '110'],
    'Nama': ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank', 'Grace', 'Hannah', 'Ivy', 'Jack'],
    'Jurusan': ['Teknik Informatika', 'Statistika', 'Matematika', 'Teknik Informatika', 'Teknik Elektro', 'Statistika', 'Teknik Elektro', 'Matematika', 'Teknik Elektro', 'Statistika'],
    'IPK': [3.5, 3.0, 3.8, 3.6, 3.2, 2.8, 3.9, 3.1, 3.5, 3.7]
}

df_mahasiswa = pd.DataFrame(data_mahasiswa)

# %% [markdown]
# ## Soal 1
# Gabungkan df_mahasiswa dengan DataFrame baru yang berisi data beasiswa berdasarkan NIM. Gunakan merge() untuk inner join.

# %%
data_beasiswa = {
    'NIM': ['103', '105', '108', '112'],
    'Beasiswa': ['Penuh', 'Sebagian', 'Penuh', 'Penuh']
}
df_beasiswa = pd.DataFrame(data_beasiswa)

# %%
# Jawaban Soal 1
df_gabung =
df_gabung
# Out:
#    NIM     Nama         Jurusan  IPK  Beasiswa
# 0  103  Charlie      Matematika  3.8     Penuh
# 1  105      Eve  Teknik Elektro  3.2  Sebagian
# 2  108   Hannah      Matematika  3.1     Penuh

# %% [markdown]
# ## Soal 2
# Buat pivot table dari df_mahasiswa untuk mengetahui rata-rata IPK tiap Jurusan.

# %%
#Jawaban
pivot_jurusan_ipk =
pivot_jurusan_ipk
# Out:
#                          IPK
# Jurusan
# Matematika          3.450000
# Statistika          3.166667
# Teknik Elektro      3.533333
# Teknik Informatika  3.550000

# %% [markdown]
# ## Soal 3
# Gunakan groupby untuk menghitung jumlah mahasiswa tiap Jurusan.

# %%
#Jawaban
jumlah_per_jurusan =
jumlah_per_jurusan
# Out:
# Jurusan
# Matematika            2
# Statistika            3
# Teknik Elektro        3
# Teknik Informatika    2
# dtype: int64

# %% [markdown]
# ## Soal 4
# Terapkan lambda function pada kolom IPK untuk mengategorikan sebagai 'Tinggi' jika IPK >= 3.5, dan 'Rendah' jika sebaliknya.

# %%
#Jawaban
df_mahasiswa['Kategori_IPK'] =
df_mahasiswa
# Out:
#    NIM     Nama             Jurusan  IPK Kategori_IPK
# 0  101    Alice  Teknik Informatika  3.5       Tinggi
# 1  102      Bob          Statistika  3.0       Rendah
# 2  103  Charlie          Matematika  3.8       Tinggi
# 3  104    David  Teknik Informatika  3.6       Tinggi
# 4  105      Eve      Teknik Elektro  3.2       Rendah
# 5  106    Frank          Statistika  2.8       Rendah
# 6  107    Grace      Teknik Elektro  3.9       Tinggi
# 7  108   Hannah          Matematika  3.1       Rendah
# 8  109      Ivy      Teknik Elektro  3.5       Tinggi
# 9  110     Jack          Statistika  3.7       Tinggi

# %% [markdown]
# ## Soal 5
# Gunakan concat() untuk menambahkan DataFrame baru yang berisi data mahasiswa baru ke df_mahasiswa secara vertikal.

# %%
data_mahasiswa_baru = {
    'NIM': ['111', '112'],
    'Nama': ['Kathy', 'Liam'],
    'Jurusan': ['Matematika', 'Teknik Informatika'],
    'IPK': [3.4, 3.6]
}
df_mahasiswa_baru = pd.DataFrame(data_mahasiswa_baru)

# %%
#Jawaban
df_total_mahasiswa =
df_total_mahasiswa
# Out:
#     NIM     Nama             Jurusan  IPK Kategori_IPK
# 0   101    Alice  Teknik Informatika  3.5       Tinggi
# 1   102      Bob          Statistika  3.0       Rendah
# 2   103  Charlie          Matematika  3.8       Tinggi
# 3   104    David  Teknik Informatika  3.6       Tinggi
# 4   105      Eve      Teknik Elektro  3.2       Rendah
# 5   106    Frank          Statistika  2.8       Rendah
# 6   107    Grace      Teknik Elektro  3.9       Tinggi
# 7   108   Hannah          Matematika  3.1       Rendah
# 8   109      Ivy      Teknik Elektro  3.5       Tinggi
# 9   110     Jack          Statistika  3.7       Tinggi
# 10  111    Kathy          Matematika  3.4          NaN
# 11  112     Liam  Teknik Informatika  3.6          NaN
